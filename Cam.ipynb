# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
cam = cv2.VideoCapture(0)
while(True):
 ret,frame = cam.read()
 if (ret):
  
  cv2.imshow('frame',frame)
  
  if cv2.waitKey(1) & 0xFF == ord('0'):
   
   break
cam.release()
cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture(0)
#H0-180 S 0-255  V 0-255
Azul_B = np.array([100,100,100],np.uint8)
Azul_A = np.array([130,255,255],np.uint8) 

cam = cv2.VideoCapture(0)
while(True):
 ret,frame = cam.read()
 if (ret):
  hsv = cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)
  mask_A = cv2.inRange(hsv,Azul_B,Azul_A)
 
  contorno,_ =cv2.findContours(mask_A,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
  c=len(contorno)
  for c in contorno:
    area=cv2.contourArea(c)
    if area>500:
      Ncontorno=cv2.convexHull(c)
      cv2.drawContours(frame,[Ncontorno],0,(0,255,255),3)
     
  cv2.imshow('COLORES',frame)
 if cv2.waitKey(1) & 0xFF == ord('0'):
   
   break
cam.release()
cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture(0)
#H0-180 S 0-255  V 0-255
Azul_B = np.array([100,100,100],np.uint8)
Azul_A = np.array([130,255,255],np.uint8) 

cam = cv2.VideoCapture(0)
while(True):
 ret,frame = cam.read()
 if (ret):
  hsv = cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)
  mask_A = cv2.inRange(hsv,Azul_B,Azul_A)
 
  contorno,_ =cv2.findContours(mask_A,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
  c=len(contorno)
  print(c)
  for c in contorno:
    
    area=cv2.contourArea(c)
    if area>500:
      Ncontorno=cv2.convexHull(c)
      cv2.drawContours(frame,[Ncontorno],0,(0,255,255),3)
     
  cv2.imshow('COLORES',frame)
 if cv2.waitKey(1) & 0xFF == ord('0'):
   
   break
cam.release()
cv2.destroyAllWindows()

# %%
#H0-180 S 0-255  V 0-255
Azul_B = np.array([100,100,100],np.uint8)
Azul_A = np.array([120,255,255],np.uint8) 

cam = cv2.VideoCapture(0)
while(True):
 ret,frame = cam.read()
 if (ret):
  hsv = cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)
  mask_A = cv2.inRange(hsv,Azul_B,Azul_A)
  contorno,_ =cv2.findContours(mask_A,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
 
 
  for (i,c) in enumerate(contorno):
    area=cv2.contourArea(c)
    if area>2500:
      Ncontorno=cv2.convexHull(c)
      perimetro = cv2.arcLength(c,True)
      
      M=cv2.moments(c)
      if (M["m00"]==0):M["m00"]=1
      x=int(M["m10"]/M["m00"])
      y=int(M["m01"]/M["m00"])
      cv2.drawContours(frame,[Ncontorno],0,(0,255,255),1)

      cv2.putText(frame,str(i+1),(x-10,y-10),3,0.75,(0,255,255),1,cv2.LINE_AA)
  contador=255*np.ones((200,200,3),dtype=np.uint8)   
  #cv2.circle(contador,(30,30),15,(255,0,0),-1)
  cv2.rectangle(contador,(20,20),(45,45),(255,0,0),2)
  cv2.putText(contador,"Azul"+" "+str(len(Ncontorno)),(65,40),3,0.50,(255,0,0),1,cv2.LINE_AA)
  cv2.imshow('Contador',contador)    
  cv2.imshow('COLORES',frame)
 if cv2.waitKey(1) & 0xFF == ord('0'):
   
   break
cam.release()
cv2.destroyAllWindows()

# %%
Azul_B = np.array([100,100,100],np.uint8)
Azul_A = np.array([120,255,255],np.uint8) 
cam = cv2.VideoCapture(0)
while(True):
 ret,frame = cam.read()
 if (ret):
  x1, y1 = 200, 100  # 
  x2, y2 = 500, 400  # 
  b=x2+x1
  h=y2+y1
  LdCon = frame[y1:y2, x1:x2].copy()


  hsv = cv2.cvtColor(LdCon,cv2.COLOR_BGR2HSV)
  mask_A = cv2.inRange(hsv,Azul_B,Azul_A)
  contorno,_ =cv2.findContours(mask_A,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)

  for (i,c) in enumerate(contorno):

    area=cv2.contourArea(c)
    if area>b+h:

      Ncontorno=cv2.convexHull(c) 
      M=cv2.moments(c)
      if (M["m00"]==0):M["m00"]=1
      x=int(M["m10"]/M["m00"])
      y=int(M["m01"]/M["m00"])

      cv2.drawContours(LdCon,[Ncontorno],0,(0,255,255),1)
      cv2.putText(frame,str(i+1),(x,y),2,0.5,(0,255,255),1,cv2.LINE_AA)
 contador=255*np.ones((200,200,3),dtype=np.uint8)   
  #cv2.circle(contador,(30,30),15,(255,0,0),-1)
 cv2.rectangle(contador,(20,20),(45,45),(255,0,0),2)
 cv2.putText(contador,"Azul"+" "+str(i+1),(65,40),3,0.50,(255,0,0),1,cv2.LINE_AA)
 cv2.imshow('Contador',contador)    

 cv2.rectangle(frame,(x1,y1),(x2,y2),(255,255,0),2)
 cv2.imshow('Imagen Original', frame)
 cv2.imshow('Región Seleccionada', LdCon)

 if cv2.waitKey(1) & 0xFF == ord('0'):
   
   break
cam.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Figuras

# %%
cam = cv2.VideoCapture(0)
while(True):
 ret,frame = cam.read()
 if (ret):
  x1, y1 = 200, 100  # 
  x2, y2 = 500, 400  # 
  b=x2+x1
  h=y2+y1
  LdCon = frame[y1:y2, x1:x2].copy()

  gris= cv2.cvtColor(LdCon,cv2.COLOR_BGR2GRAY)
  media=cv2.GaussianBlur(gris,(9,9),0)
  #unbral = cv2.Canny(media,20,50)
  _,unbral=cv2.threshold(media,100,250,cv2.THRESH_BINARY,cv2.THRESH_OTSU)
   #unbral=cv2.dilate(unbral,None,iterations=1)
  #unbral=cv2.erode(unbral,None,iterations=1)
  contorno,_ =cv2.findContours(unbral,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
  for (i,c) in enumerate(contorno):
    area=cv2.contourArea(c)
    if area>b+h:
      Ncontorno=cv2.convexHull(c)
      cv2.drawContours(frame,[Ncontorno],0,(0,255,255),2)
      perimetro=cv2.arcLength(c,True)
      aprox=cv2.approxPolyDP(c,0.02*perimetro,True)
      print("area ",area)
      print("perimetro ",perimetro)
      print("Contorno ", len(aprox))
      x,y,w,h=cv2.boundingRect(aprox)

      lados=len(aprox)
      if lados==3:
        #objetype="T"
        cv2.putText(frame,"T",(x1+(w//2)-10,y1+(h//2)-10),cv2.FONT_HERSHEY_COMPLEX_SMALL,0.5,(0,255,255),1,cv2.LINE_AA)
      elif lados==4:
        condicion=w/float(h)
        if condicion >0.95 and condicion<1.05:
           #objetype="Cu"
           cv2.putText(frame,"Cuadrado",(x+(w//2)-10,y+(h//2)-10),cv2.FONT_HERSHEY_COMPLEX_SMALL,0.5,(0,255,255),0,cv2.LINE_AA)
        else :
           #objetype="R"
           cv2.putText(frame,"R",(x1+(w//2)-10,y1+(h//2)-10),cv2.FONT_HERSHEY_COMPLEX_SMALL,0.5,(0,255,255),1,cv2.LINE_AA)
      elif lados==5:
         #objetype="P"
         cv2.putText(frame,"P",(x1+(w//2)-10,y1+(h//2)-10),cv2.FONT_HERSHEY_COMPLEX_SMALL,0.5,(0,255,255),1,cv2.LINE_AA)
      elif lados >5 and lados < 15:
         #objetype="C"
         cv2.putText(frame,"C",(x+(w//2)-10,y+(h//2)-10),cv2.FONT_HERSHEY_COMPLEX_SMALL,0.5,(0,255,255),1,cv2.LINE_AA)
      else:  
       cv2.putText(frame," ",(x+(w//2)-10,y1+(h//2)-10),cv2.FONT_HERSHEY_COMPLEX_SMALL,0.5,(0,255,255),1,cv2.LINE_AA)


 cv2.rectangle(frame,(x1,y1),(x2,y2),(255,255,0),2)
 cv2.imshow('Imagen Original', frame)
 cv2.imshow('Unbral', unbral)
 cv2.imshow('MEDIA', media)
 cv2.imshow('Región Seleccionada', LdCon)

 if cv2.waitKey(1) & 0xFF == ord('0'):
   
   break
cam.release()
cv2.destroyAllWindows()
